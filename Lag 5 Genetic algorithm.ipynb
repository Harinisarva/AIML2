# %% [markdown]
# <a href="https://colab.research.google.com/github/Harinisarva/AIML2/blob/main/Lag%205%20Genetic%20algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print("lab 5:", )
POPULATION_SIZE = 100

GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

TARGET = "I love GeeksforGeeks"

class Individual:
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()

    @classmethod
    def mutated_genes(cls):
        return random.choice(GENES)

    @classmethod
    def create_gnome(cls):
        gnome_len = len(TARGET)
        return [cls.mutated_genes() for _ in range(gnome_len)]

    def mate(self, partner):
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, partner.chromosome):
            prob = random.random()
            if prob < 0.45:
                child_chromosome.append(gp1)
            elif prob < 0.90:
                child_chromosome.append(gp2)
            else:
                child_chromosome.append(self.mutated_genes())
        return Individual(child_chromosome)

    def cal_fitness(self):
        return sum(1 for gs, gt in zip(self.chromosome, TARGET) if gs != gt)

def main():
    global POPULATION_SIZE

    generation = 1
    found = False
    population = []
    for _ in range(POPULATION_SIZE):
        gnome = Individual.create_gnome()
        population.append(Individual(gnome))

    while not found:
        population = sorted(population, key=lambda x: x.fitness)

        if population[0].fitness <= 0:
            found = True
            break

        new_generation = []

        s = int((10 * POPULATION_SIZE) / 100)
        new_generation.extend(population[:s])

        s = int((90 * POPULATION_SIZE) / 100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)

        population = new_generation

        print("Generation: {}\tString: {}\tFitness: {}".format(
            generation,
            "".join(population[0].chromosome),
            population[0].fitness))

        generation += 1

    print("Generation: {}\tString: {}\tFitness: {}".format(
        generation,
        "".join(population[0].chromosome),
        population[0].fitness))

if __name__ == '__main__':
    main()
# Out:
# lab 5:
# Generation: 1	String: QF4o#/ vL Mh1tV@_obG	Fitness: 18
# Generation: 2	String: fEKogdH1?f,_f/W!0kTs	Fitness: 17
# Generation: 3	String: fEKogdH1?f,_f/W!0kTs	Fitness: 17
# Generation: 4	String: fEKogdH1?f,_f/W!0kTs	Fitness: 17
# Generation: 5	String: o :oLe . s,rvfa0i-ga	Fitness: 16
# Generation: 6	String: f({o!e .?(k_8/]G0 Ts	Fitness: 14
# Generation: 7	String: f({o!e .?(k_8/]G0 Ts	Fitness: 14
# Generation: 8	String: bO"oje G?EY[f/2de gs	Fitness: 13
# Generation: 9	String: bO"oje G?EY[f/2de gs	Fitness: 13
# Generation: 10	String: w loPe .?TY[foR8 -Is	Fitness: 12
# Generation: 11	String: q loIe Ge(,sf[]EU }s	Fitness: 10
# Generation: 12	String: q loIe Ge(,sf[]EU }s	Fitness: 10
# Generation: 13	String: , love Ge(kXfR]XUsIs	Fitness: 9
# Generation: 14	String: , love Ge(kXfR]XUsIs	Fitness: 9
# Generation: 15	String: , love Ge(kXfR]XUsIs	Fitness: 9
# Generation: 16	String: p loGe;GqekrfoWG3e7s	Fitness: 8
# Generation: 17	String: f love;GiekwfoEGMe7s	Fitness: 7
# Generation: 18	String: f love;GiekwfoEGMe7s	Fitness: 7
# Generation: 19	String: f lovemGeeksfo Geeas	Fitness: 4
# Generation: 20	String: f lovemGeeksfo Geeas	Fitness: 4
# Generation: 21	String: f lovemGeeksfo Geeas	Fitness: 4
# Generation: 22	String: f lovemGeeksfo Geeas	Fitness: 4
# Generation: 23	String: f lovemGeeksfo Geeas	Fitness: 4
# Generation: 24	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 25	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 26	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 27	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 28	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 29	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 30	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 31	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 32	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 33	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 34	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 35	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 36	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 37	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 38	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 39	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 40	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 41	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 42	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 43	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 44	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 45	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 46	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 47	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 48	String: p love GeeksfoaGeeas	Fitness: 3
# Generation: 49	String: . love GeeksforGeews	Fitness: 2
# Generation: 50	String: . love GeeksforGeews	Fitness: 2
# Generation: 51	String: . love GeeksforGeews	Fitness: 2
# Generation: 52	String: . love GeeksforGeews	Fitness: 2
# Generation: 53	String: . love GeeksforGeews	Fitness: 2
# Generation: 54	String: . love GeeksforGeews	Fitness: 2
# Generation: 55	String: . love GeeksforGeews	Fitness: 2
# Generation: 56	String: . love GeeksforGeews	Fitness: 2
# Generation: 57	String: . love GeeksforGeews	Fitness: 2
# Generation: 58	String: . love GeeksforGeews	Fitness: 2
# Generation: 59	String: . love GeeksforGeews	Fitness: 2
# Generation: 60	String: . love GeeksforGeews	Fitness: 2
# Generation: 61	String: . love GeeksforGeews	Fitness: 2
# Generation: 62	String: . love GeeksforGeews	Fitness: 2
# Generation: 63	String: . love GeeksforGeews	Fitness: 2
# Generation: 64	String: . love GeeksforGeews	Fitness: 2
# Generation: 65	String: . love GeeksforGeews	Fitness: 2
# Generation: 66	String: , love GeeksforGeeks	Fitness: 1
# Generation: 67	String: , love GeeksforGeeks	Fitness: 1
# Generation: 68	String: , love GeeksforGeeks	Fitness: 1
# Generation: 69	String: , love GeeksforGeeks	Fitness: 1
# Generation: 70	String: , love GeeksforGeeks	Fitness: 1
# Generation: 71	String: , love GeeksforGeeks	Fitness: 1
# Generation: 72	String: , love GeeksforGeeks	Fitness: 1
# Generation: 73	String: , love GeeksforGeeks	Fitness: 1
# Generation: 74	String: , love GeeksforGeeks	Fitness: 1
# Generation: 75	String: , love GeeksforGeeks	Fitness: 1
# Generation: 76	String: , love GeeksforGeeks	Fitness: 1
# Generation: 77	String: , love GeeksforGeeks	Fitness: 1
# Generation: 78	String: , love GeeksforGeeks	Fitness: 1
# Generation: 79	String: , love GeeksforGeeks	Fitness: 1
# Generation: 80	String: , love GeeksforGeeks	Fitness: 1
# Generation: 81	String: , love GeeksforGeeks	Fitness: 1
# Generation: 82	String: , love GeeksforGeeks	Fitness: 1
# Generation: 83	String: , love GeeksforGeeks	Fitness: 1
# Generation: 84	String: , love GeeksforGeeks	Fitness: 1
# Generation: 85	String: , love GeeksforGeeks	Fitness: 1
# Generation: 86	String: , love GeeksforGeeks	Fitness: 1
# Generation: 87	String: , love GeeksforGeeks	Fitness: 1
# Generation: 88	String: , love GeeksforGeeks	Fitness: 1
# Generation: 89	String: , love GeeksforGeeks	Fitness: 1
# Generation: 90	String: , love GeeksforGeeks	Fitness: 1
# Generation: 91	String: , love GeeksforGeeks	Fitness: 1
# Generation: 92	String: , love GeeksforGeeks	Fitness: 1
# Generation: 93	String: , love GeeksforGeeks	Fitness: 1
# Generation: 94	String: , love GeeksforGeeks	Fitness: 1
# Generation: 95	String: , love GeeksforGeeks	Fitness: 1
# Generation: 96	String: , love GeeksforGeeks	Fitness: 1
# Generation: 97	String: , love GeeksforGeeks	Fitness: 1
# Generation: 98	String: , love GeeksforGeeks	Fitness: 1
# Generation: 99	String: , love GeeksforGeeks	Fitness: 1
# Generation: 100	String: , love GeeksforGeeks	Fitness: 1
# Generation: 101	String: , love GeeksforGeeks	Fitness: 1
# Generation: 102	String: , love GeeksforGeeks	Fitness: 1
# Generation: 103	String: , love GeeksforGeeks	Fitness: 1
# Generation: 104	String: , love GeeksforGeeks	Fitness: 1
# Generation: 105	String: , love GeeksforGeeks	Fitness: 1
# Generation: 106	String: , love GeeksforGeeks	Fitness: 1
# Generation: 107	String: , love GeeksforGeeks	Fitness: 1
# Generation: 108	String: , love GeeksforGeeks	Fitness: 1
# Generation: 109	String: , love GeeksforGeeks	Fitness: 1
# Generation: 110	String: , love GeeksforGeeks	Fitness: 1
# Generation: 111	String: , love GeeksforGeeks	Fitness: 1
# Generation: 112	String: , love GeeksforGeeks	Fitness: 1
# Generation: 113	String: , love GeeksforGeeks	Fitness: 1
# Generation: 114	String: , love GeeksforGeeks	Fitness: 1
# Generation: 115	String: , love GeeksforGeeks	Fitness: 1
# Generation: 116	String: , love GeeksforGeeks	Fitness: 1
# Generation: 117	String: , love GeeksforGeeks	Fitness: 1
# Generation: 118	String: , love GeeksforGeeks	Fitness: 1
# Generation: 119	String: , love GeeksforGeeks	Fitness: 1
# Generation: 120	String: , love GeeksforGeeks	Fitness: 1
# Generation: 121	String: , love GeeksforGeeks	Fitness: 1
# Generation: 122	String: , love GeeksforGeeks	Fitness: 1
# Generation: 123	String: , love GeeksforGeeks	Fitness: 1
# Generation: 124	String: , love GeeksforGeeks	Fitness: 1
# Generation: 125	String: , love GeeksforGeeks	Fitness: 1
# Generation: 126	String: , love GeeksforGeeks	Fitness: 1
# Generation: 127	String: , love GeeksforGeeks	Fitness: 1
# Generation: 128	String: , love GeeksforGeeks	Fitness: 1
# Generation: 129	String: , love GeeksforGeeks	Fitness: 1
# Generation: 130	String: , love GeeksforGeeks	Fitness: 1
# Generation: 131	String: , love GeeksforGeeks	Fitness: 1
# Generation: 132	String: , love GeeksforGeeks	Fitness: 1
# Generation: 133	String: , love GeeksforGeeks	Fitness: 1
# Generation: 134	String: , love GeeksforGeeks	Fitness: 1
# Generation: 135	String: , love GeeksforGeeks	Fitness: 1
# Generation: 136	String: , love GeeksforGeeks	Fitness: 1
# Generation: 137	String: , love GeeksforGeeks	Fitness: 1
# Generation: 138	String: , love GeeksforGeeks	Fitness: 1
# Generation: 139	String: , love GeeksforGeeks	Fitness: 1
# Generation: 140	String: , love GeeksforGeeks	Fitness: 1
# Generation: 141	String: , love GeeksforGeeks	Fitness: 1
# Generation: 142	String: , love GeeksforGeeks	Fitness: 1
# Generation: 143	String: , love GeeksforGeeks	Fitness: 1
# Generation: 144	String: , love GeeksforGeeks	Fitness: 1
# Generation: 145	String: , love GeeksforGeeks	Fitness: 1
# Generation: 146	String: , love GeeksforGeeks	Fitness: 1
# Generation: 147	String: , love GeeksforGeeks	Fitness: 1
# Generation: 148	String: , love GeeksforGeeks	Fitness: 1
# Generation: 149	String: , love GeeksforGeeks	Fitness: 1
# Generation: 150	String: , love GeeksforGeeks	Fitness: 1
# Generation: 151	String: , love GeeksforGeeks	Fitness: 1
# Generation: 152	String: , love GeeksforGeeks	Fitness: 1
# Generation: 153	String: , love GeeksforGeeks	Fitness: 1
# Generation: 154	String: , love GeeksforGeeks	Fitness: 1
# Generation: 155	String: , love GeeksforGeeks	Fitness: 1
# Generation: 156	String: , love GeeksforGeeks	Fitness: 1
# Generation: 157	String: , love GeeksforGeeks	Fitness: 1
# Generation: 158	String: , love GeeksforGeeks	Fitness: 1
# Generation: 159	String: , love GeeksforGeeks	Fitness: 1
# Generation: 160	String: , love GeeksforGeeks	Fitness: 1
# Generation: 161	String: , love GeeksforGeeks	Fitness: 1
# Generation: 162	String: , love GeeksforGeeks	Fitness: 1
# Generation: 163	String: , love GeeksforGeeks	Fitness: 1
# Generation: 164	String: , love GeeksforGeeks	Fitness: 1
# Generation: 165	String: , love GeeksforGeeks	Fitness: 1
# Generation: 166	String: , love GeeksforGeeks	Fitness: 1
# Generation: 167	String: , love GeeksforGeeks	Fitness: 1
# Generation: 168	String: , love GeeksforGeeks	Fitness: 1
# Generation: 169	String: , love GeeksforGeeks	Fitness: 1
# Generation: 170	String: , love GeeksforGeeks	Fitness: 1
# Generation: 171	String: , love GeeksforGeeks	Fitness: 1
# Generation: 172	String: , love GeeksforGeeks	Fitness: 1
# Generation: 173	String: , love GeeksforGeeks	Fitness: 1
# Generation: 174	String: , love GeeksforGeeks	Fitness: 1
# Generation: 175	String: , love GeeksforGeeks	Fitness: 1
# Generation: 176	String: , love GeeksforGeeks	Fitness: 1
# Generation: 177	String: , love GeeksforGeeks	Fitness: 1
# Generation: 178	String: , love GeeksforGeeks	Fitness: 1
# Generation: 179	String: , love GeeksforGeeks	Fitness: 1
# Generation: 180	String: , love GeeksforGeeks	Fitness: 1
# Generation: 181	String: , love GeeksforGeeks	Fitness: 1
# Generation: 182	String: , love GeeksforGeeks	Fitness: 1
# Generation: 183	String: , love GeeksforGeeks	Fitness: 1
# Generation: 184	String: , love GeeksforGeeks	Fitness: 1
# Generation: 185	String: , love GeeksforGeeks	Fitness: 1
# Generation: 186	String: , love GeeksforGeeks	Fitness: 1
# Generation: 187	String: , love GeeksforGeeks	Fitness: 1
# Generation: 188	String: , love GeeksforGeeks	Fitness: 1
# Generation: 189	String: , love GeeksforGeeks	Fitness: 1
# Generation: 190	String: , love GeeksforGeeks	Fitness: 1
# Generation: 191	String: , love GeeksforGeeks	Fitness: 1
# Generation: 192	String: , love GeeksforGeeks	Fitness: 1
# Generation: 193	String: , love GeeksforGeeks	Fitness: 1
# Generation: 194	String: , love GeeksforGeeks	Fitness: 1
# Generation: 195	String: , love GeeksforGeeks	Fitness: 1
# Generation: 196	String: , love GeeksforGeeks	Fitness: 1
# Generation: 197	String: , love GeeksforGeeks	Fitness: 1
# Generation: 198	String: , love GeeksforGeeks	Fitness: 1
# Generation: 199	String: , love GeeksforGeeks	Fitness: 1
# Generation: 200	String: , love GeeksforGeeks	Fitness: 1
# Generation: 201	String: , love GeeksforGeeks	Fitness: 1
# Generation: 202	String: , love GeeksforGeeks	Fitness: 1
# Generation: 203	String: , love GeeksforGeeks	Fitness: 1
# Generation: 204	String: , love GeeksforGeeks	Fitness: 1
# Generation: 205	String: , love GeeksforGeeks	Fitness: 1
# Generation: 206	String: , love GeeksforGeeks	Fitness: 1
# Generation: 207	String: , love GeeksforGeeks	Fitness: 1
# Generation: 208	String: , love GeeksforGeeks	Fitness: 1
# Generation: 209	String: , love GeeksforGeeks	Fitness: 1
# Generation: 210	String: , love GeeksforGeeks	Fitness: 1
# Generation: 211	String: , love GeeksforGeeks	Fitness: 1
# Generation: 212	String: , love GeeksforGeeks	Fitness: 1
# Generation: 213	String: , love GeeksforGeeks	Fitness: 1
# Generation: 214	String: , love GeeksforGeeks	Fitness: 1
# Generation: 215	String: , love GeeksforGeeks	Fitness: 1
# Generation: 216	String: , love GeeksforGeeks	Fitness: 1
# Generation: 217	String: , love GeeksforGeeks	Fitness: 1
# Generation: 218	String: , love GeeksforGeeks	Fitness: 1
# Generation: 219	String: , love GeeksforGeeks	Fitness: 1
# Generation: 220	String: , love GeeksforGeeks	Fitness: 1
# Generation: 221	String: , love GeeksforGeeks	Fitness: 1
# Generation: 222	String: , love GeeksforGeeks	Fitness: 1
# Generation: 223	String: , love GeeksforGeeks	Fitness: 1
# Generation: 224	String: , love GeeksforGeeks	Fitness: 1
# Generation: 225	String: , love GeeksforGeeks	Fitness: 1
# Generation: 226	String: , love GeeksforGeeks	Fitness: 1
# Generation: 227	String: , love GeeksforGeeks	Fitness: 1
# Generation: 228	String: , love GeeksforGeeks	Fitness: 1
# Generation: 229	String: , love GeeksforGeeks	Fitness: 1
# Generation: 230	String: , love GeeksforGeeks	Fitness: 1
# Generation: 231	String: , love GeeksforGeeks	Fitness: 1
# Generation: 232	String: , love GeeksforGeeks	Fitness: 1
# Generation: 233	String: , love GeeksforGeeks	Fitness: 1
# Generation: 234	String: , love GeeksforGeeks	Fitness: 1
# Generation: 235	String: , love GeeksforGeeks	Fitness: 1
# Generation: 236	String: , love GeeksforGeeks	Fitness: 1
# Generation: 237	String: I love GeeksforGeeks	Fitness: 0
