# %% [markdown]
# <a href="https://colab.research.google.com/github/Harinisarva/AIML2/blob/main/Assignment%201%20part%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_table("Lab01-Text.txt")

# %%
df1
# Out:
#             hii
# 0         hello
# 1  how are you?

# %%
data2=pd.read_csv("Lab01-Text.csv")

# %%
data2
# Out:
#             hii
# 0         hello
# 1  how are you?
